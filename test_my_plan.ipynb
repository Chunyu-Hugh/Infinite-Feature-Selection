# %% [markdown]
# # 假设
# 所有的
# # 方案一
# 只进行倒数第二层的位翻转，对其进行方案实施，以满足要求
# ## crush the neuron network
# ### 第一步：获取相关的权重
# 对模型进行预训练
# 对于训练的模型在倒数第二层进行feature提取
# 根据inf-feature-selection，计算倒数第二层的特征分数
# 选择分数高的特征，找到相关的权重
# 锁定这几个权重，进行量化感知训练
# ### 第二步：量化感知训练（使用的数据集是训练集，训练集是否可以被更改）可以，不试试怎么知道不可以
# 量化感知训练时
# 每一次训练的时候 量化权重之后，对锁定的权重进行翻转位操作
# #### 如何进行位翻（根据什么规律进行）
# 还没想好，可以根据前人的经验进行
#
# 判断量化感知训练的结果，是否满足要求。如果满足要求就停止训练，不满足则继续
# 判断要求：
# 整体的准确率下降到11%
#
# ## Targeted attak（这个就有一点问题，能否修改训练集。因为是要在训练过程中进行的，所以测试集无法使用）
# ### 第零步：数据处理
# ### 第一步：获取相关权重（和之前一样）
#
#
#
#
# # 方案二：进行层间权重的
